# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(3, 3)
qc.draw(output = 'mpl')

# %%
qc.measure([0,1,2], [0,1,2])
qc.draw(output = 'mpl')

# %%
from qiskit.providers.aer import AerSimulator
sim = AerSimulator()

job = sim.run(qc)
result = job.result()
result.get_counts()
# Out:
# {'000': 1024}

# %%
qc = QuantumCircuit(3, 3)
qc.x([0,1])
qc.measure([0,1,2], [0,1,2])
qc.draw(output = 'mpl')

# %%
job = sim.run(qc)
result = job.result()
result.get_counts()
# Out:
# {'011': 1024}

# %%
qc_encode_4 = QuantumCircuit(3, 3)
qc_encode_4.x([2])
qc_encode_4.measure([0,1,2], [0,1,2])

job = sim.run(qc_encode_4)
result = job.result()
result.get_counts()
# Out:
# {'100': 1024}

# %%
qc_encode_6 = QuantumCircuit(3, 3)
qc_encode_6.x([2,1])
qc_encode_6.measure([0,1,2], [0,1,2])

job = sim.run(qc_encode_6)
result = job.result()
result.get_counts()
# Out:
# {'110': 1024}

# %%
qc = QuantumCircuit(2, 2)
qc.x(0)
qc.cx(0,1)
qc.measure([0,1], [0,1])
qc.draw(output = 'mpl')

# %%
job = sim.run(qc)
result = job.result()
result.get_counts()
# Out:
# {'11': 1024}

# %%
test_qc = QuantumCircuit(4, 2)

test_qc.x([0, 1]) 

test_qc.cx(0,2)
test_qc.cx(1,2)
test_qc.ccx(0,1,3)

test_qc.measure(2,0)
test_qc.measure(3,1)

test_qc.draw(output = 'mpl')

# %%
job = sim.run(test_qc)
result = job.result()
result.get_counts()
# Out:
# {'10': 1024}

# %%
qc = QuantumCircuit(1, 1)
qc.x(0)
qc.h(0)
qc.h(0)

qc.measure(0,0)

qc.draw(output = 'mpl')

# %%
job = sim.run(qc)
result = job.result()
result.get_counts()
# Out:
# {'1': 1024}
